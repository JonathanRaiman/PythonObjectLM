# %%
# %load_ext cythonmagic
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
import numpy as np, os, sys, gzip, pickle, re
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'png'
from collections import OrderedDict
from word2vec_extended import Word2VecExtended
from IPython.display import clear_output
from utils import present_restaurant, get_adjacency_matrix, get_degree_matrix, assign_parents
from IPython.display import display, HTML
from IPython.html.widgets import interact, fixed, IntSliderWidget
from scipy.cluster.hierarchy import linkage, to_tree, dendrogram
from tsne import bh_sne
sys.path.append("/Users/jonathanraiman/Desktop/Coding/language_modeling/")
from objectlm import ObjectLM, CategoriesConverter, DatasetGenerator, HierarchicalObservation
lmsenti = Word2VecExtended.load("/Users/jonathanraiman/Desktop/Coding/language_modeling/saves/kid_model_30_oov_senti")

# %%
file = gzip.open("saves/saved_texts.gz", 'r')
texts, texts_data = pickle.load(file)
file.close()
categories = set()
for el in texts_data:
    for c in el["categories"]:
        categories.add(c)
catconvert = CategoriesConverter(categories)
dataset_gen = DatasetGenerator(texts, texts_data, catconvert)

# should modify this to do some auto-encoding / self regression.
model = ObjectLM(
    vocabulary = lmsenti,
    object_vocabulary_size = len(texts),
    window = 10,
    bilinear_form = False,
    size = 20,
    object_size = 20,
    output_sigmoid_classes = catconvert.num_categories,
    output_sigmoid_labels = catconvert.index2category,
    output_labels = [["", "$", "$$", "$$$", "$$$$"], ["1", "2", "3", "4", "5"]],
    output_classes=[5, 5] # "", "$", "$$",...,"$$$$", 5 price classes, and 5 rating classes
)
model.load_saved_weights("saves/objectlm_window_10_lm_20_objlm_20_4/")
model.create_normalized_matrices()


if os.path.exists("saves/__linkage_average.npy"):
    Z = np.load("saves/__linkage_average.npy")
else:
    y = model.object_matrix.get_value(borrow=True)
    Z = linkage(y, method='average', metric='cosine')
    np.save("saves/__linkage_average.npy", Z)
    
    
if os.path.exists("saves/__covariance__.npy"):
    Cov = np.load("saves/__covariance__.npy")
    observables = HierarchicalObservation(Cov)
else:
    root, nodes = to_tree(Z, rd=True)
    assign_parents(root)
    adj_mat = get_adjacency_matrix(nodes_small)
    deg_mat = get_degree_matrix(nodes_small)
    sigma = 5
    laplacian = np.diag(deg_mat) - adj_mat + 1/(sigma**2) * np.eye(len(deg_mat))
    Cov = np.linalg.inv(laplacian)[0:model.object_vocabulary_size,0:model.object_vocabulary_size]
    np.save("saves/__covariance__.npy", Cov)
    observables = HierarchicalObservation(Cov)
    
    
from pyxdameraulevenshtein import damerau_levenshtein_distance as levenshtein_distance

def search_for_object(self, object_index, topn = 10, metric = 'cosine'):
    present_restaurant(texts_data[object_index], text = texts[object_index])
    display(HTML("<small>%d</small>" % object_index))
    
    print(object_index)
    
    results = self.most_similar_object(object_index, topn=topn, metric = metric)
    if metric == 'euclidean':
        max_distance = max(result[1] for result in results)
    else:
        max_distance = 1
    
    for result, distance in results:
        present_restaurant(texts_data[result], text = texts[result])
        display(HTML("<small>%d</small>" % result))
        display(HTML("""
            <div>
                <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
                    <div style='height:20px; width:%dpx;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
                        # %.0f%%
                    </div>
                </div>
            </div>
            """ % (int(distance * 100 / max_distance), distance * 100 / max_distance)))
        
def nearest_name(text, levenshtein = True):
    text = text.lower()
    min_distance_index = -1
    min_distance = float('inf')
    min_distance_word = None
    
    for i, datum in enumerate(texts_data):
        if levenshtein:
            min_local_distance = float('inf')
            if datum["_id"].lower().find(text) != -1:
                min_local_distance = 3
                if min_local_distance < min_distance:
                    min_distance_word = datum["_id"]
                    min_distance = min_local_distance
                    min_distance_index = i
            for scrap in re.split( "[ -]", datum["_id"].lower()) + [datum["_id"].lower()] + datum["categories"]:
                min_local_distance = min(min_local_distance, levenshtein_distance(text, scrap))
                if min_local_distance < min_distance:
                    min_distance_word = scrap
                    min_distance = min_local_distance
                    min_distance_index = i
            if min_distance <= 1:
                break
        else:
            if datum["_id"].lower().find(text) != -1 or datum["id"].lower().find(text) != -1:
                min_distance = i
                break
            for cat in datum["categories"]:
                if cat.lower().find(text) != -1:
                    min_distance = i
                    break
    
    
    if min_distance_index == -1 or min_distance == len(text) or min_distance == len(min_distance_word):
        return (None, None, None)
    else:
        return (min_distance_word, min_distance_index, min_distance)

def search_with_text(self, text, topn = 10, levenshtein = True, metric = 'cosine'):
    min_distance_word, min_distance_index, min_distance = nearest_name(text, levenshtein=levenshtein)
    
    if min_distance_index == None:
        print("Could not be found")
    else:
        if min_distance > 0:
            display(HTML("""
            <span style="color: #333">Did you mean </span> <b>%s</b> <span style="color: #333">(%d edit%s)</span> ?
            """ % (min_distance_word, min_distance, "s" if min_distance != 1 else "")))
        return search_for_object(self, min_distance_index, topn=topn, metric = metric)
    
INDEX_SET = set(range(0,model.object_vocabulary_size))

def show_conditional_probs(query="thai", topn=20, testn=2):
    min_distance_word, min_distance_index, min_distance = nearest_name(query)
    test_indices = [min_distance_index] + [i[0] for i in model.most_similar_object(min_distance_index)][:testn-1]
    result_inds, result_probs = observables.conditional_probabilities(test_indices, remaining_indices = list(INDEX_SET - set(test_indices)))

    top_results = np.argsort(result_probs[:,0])[::-1][:topn]

    for i in range(topn):
        present_restaurant(texts_data[result_inds[top_results[i]]], text=texts[result_inds[top_results[i]]])
        print(result_probs[top_results[i],0])
        
def show_conditional_probs_from_index(indices, topn=20):
    result_inds, result_probs = observables.conditional_probabilities(indices, remaining_indices = list(INDEX_SET - set(indices)))

    top_results = np.argsort(result_probs[:,0])[::-1][:topn]

    for i in range(topn):
        present_restaurant(texts_data[result_inds[top_results[i]]], text=texts[result_inds[top_results[i]]])
        print(result_probs[top_results[i],0])

# %%
model.most_similar_word("spicy", topn = 10, metric='euclidean')
# Out:
# [('rolls', 0.22634069621562958, 39543),
#  ('curry', 0.2601078450679779, 4149),
#  ('sweet', 0.28541192412376404, 23074),
#  ('taste', 0.3037929832935333, 10084),
#  ('lunch', 0.30719003081321716, 39933),
#  ('else', 0.31810954213142395, 22305),
#  ('soup', 0.3437389135360718, 3839),
#  ('dishes', 0.34431201219558716, 23783),
#  ('found', 0.3495505154132843, 26261),
#  ('dish', 0.3529817759990692, 18811)]

# %%
model.most_similar_word("bland", topn = 10, metric='euclidean')
# Out:
# [('plain', 0.17321105301380157, 7394),
#  ('became', 0.17639024555683136, 12233),
#  ('setting', 0.2001669853925705, 11405),
#  ('prime', 0.20130905508995056, 11328),
#  ('bun', 0.20869243144989014, 30449),
#  ('money', 0.20930257439613342, 35677),
#  ('toasted', 0.21201221644878387, 18297),
#  ('tv', 0.22010065615177155, 44339),
#  ('thanks', 0.22213168442249298, 8716),
#  ('seasoned', 0.2229466289281845, 30527)]

# %%
model.most_similar_word("cancer", topn = 10, metric='euclidean')
# Out:
# [('wicked', 0.1603238880634308, 7098),
#  ('forgetting', 0.16060882806777954, 17087),
#  ('insane', 0.16438277065753937, 37478),
#  ('tiger', 0.16671735048294067, 28578),
#  ('cases', 0.16948099434375763, 21099),
#  ('powdered', 0.16957665979862213, 23867),
#  ('storage', 0.17332720756530762, 35628),
#  ('counters', 0.175497904419899, 39190),
#  ('patron', 0.17726223170757294, 24460),
#  ('radio', 0.17757530510425568, 23615)]

# %%
model.most_similar_word("sandwich", topn = 10, metric='euclidean')
# Out:
# [('bread', 0.4151478409767151, 23558),
#  ('right', 0.4159706234931946, 38326),
#  ('burger', 0.4447084367275238, 10504),
#  ('sure', 0.45078912377357483, 33424),
#  ('sandwiches', 0.4596808850765228, 39690),
#  ('fast', 0.46083134412765503, 31767),
#  ('better', 0.4627241790294647, 8050),
#  ('sauce', 0.48590564727783203, 39287),
#  ('coming', 0.48857972025871277, 18235),
#  ('make', 0.4887189269065857, 12353)]

# %%
model.most_similar_word("sandwich", topn = 10, metric='cosine')
# Out:
# [('bread', 0.9562628269195557, 23558),
#  ('right', 0.9553717374801636, 38326),
#  ('idea', 0.9483616352081299, 31262),
#  ('ago', 0.9467175006866455, 14050),
#  ('make', 0.9464825987815857, 12353),
#  ('while', 0.9453556537628174, 20071),
#  ('burger', 0.9448192119598389, 10504),
#  ('many', 0.943671464920044, 29489),
#  ('sure', 0.9435602426528931, 33424),
#  ('someone', 0.943207859992981, 10163)]

# %%
interact(search_with_text, self=fixed(model), levenshtein_distance=fixed(True), text="Tangerine Thai", metric=('cosine', 'euclidean'))
# Out:
#     <div>
#         <h2>The Lemongrass</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span><span>$</span><span>$</span></span><span style='color: #e4e4e4;'></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>1257 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>looking for flavorful warms your heart filled with love goodness , than this is the place . they have an awesome selection of authentic vietnamese food . i had the</p>
#     </div>
# <small>1334</small>
# 1334
#     <div>
#         <h2>Fremont 1AM</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>3925 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>bowl pho ... despite their poorly chosen name . the tofu spring rolls are warm , full of noodles , and delicious . especially when smothered in their extra good</p>
#     </div>
# <small>5158</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:76px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         76%
#                     </div>
#                 </div>
#             </div>
#     <div>
#         <h2>pho-vietnam-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>5447 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>thai and the simple staples that you come to expect like fresh spring rolls are very good here . it 's everything that you want from simple thai food as</p>
#     </div>
# <small>3653</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:75px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         75%
#                     </div>
#                 </div>
#             </div>
#     <div>
#         <h2>bún-vietnamese-creative-rice-noodles-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>7072 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>at thanh vi features the freshest ... read more '' mountain view , ca i like that this place is clean compared to other vietnamese restaurants in the area .</p>
#     </div>
# <small>4257</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:75px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         75%
#                     </div>
#                 </div>
#             </div>
#     <div>
#         <h2>fremont-1am-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>3985 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>thai and the simple staples that you come to expect like fresh spring rolls are very good here . it 's everything that you want from simple thai food as</p>
#     </div>
# <small>3706</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:74px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         75%
#                     </div>
#                 </div>
#             </div>
#     <div>
#         <h2>Pho Tien</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>247 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>who comes in . today i took the pipster to lunch - started with egg roll and spring roll ( they were just ok ) . we got the lunch</p>
#     </div>
# <small>1228</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:74px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         75%
#                     </div>
#                 </div>
#             </div>
#     <div>
#         <h2>the-lemongrass-renton</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>7564 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>at thanh vi features the freshest ... read more '' kent , wa this restaurant is situated close to grady wayacross the street from the park and ride . the</p>
#     </div>
# <small>5388</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:74px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         75%
#                     </div>
#                 </div>
#             </div>
#     <div>
#         <h2>Pho Bac Cafe</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>4006 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>d . 21 beef short ribs and rice by julia w . '' this is the best place to get your pho and spring rolls . '' '' ... is</p>
#     </div>
# <small>5623</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:74px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         75%
#                     </div>
#                 </div>
#             </div>
#     <div>
#         <h2>pho-tran-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>5724 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>been , i will be the happiest person . chan seattle did not disappoint in that respect . i finally made it to the restaurant on christmas eve to start</p>
#     </div>
# <small>3965</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:72px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         73%
#                     </div>
#                 </div>
#             </div>
#     <div>
#         <h2>pho-viet-anh-seattle-2</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>2575 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>at thanh vi features the freshest ... read more '' seattle , wa went there tonight and they were the busiest i 've ever seen them as it was new</p>
#     </div>
# <small>3977</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:72px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         73%
#                     </div>
#                 </div>
#             </div>
#     <div>
#         <h2>pho-city-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>990 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>had lots of chicken & the broth was tasty . the small was $ 5 ( pretty standard ) , service was quick & friendly . i was here around</p>
#     </div>
# <small>324</small>
#             <div>
#                 <div style='background: rgb(221,222,223);width:102px;padding:1px;border-radius:2px'>
#                     <div style='height:20px; width:72px;padding-left:3px;background-color:rgb(71, 189, 249);font-size:9px;color:white'>
#                         73%
#                     </div>
#                 </div>
#             </div>

# %%
interact(show_conditional_probs,
         topn=IntSliderWidget(min=1, max=100, value = 20),
         testn=IntSliderWidget(min=1, max=100, value=3))
# Out:
#     <div>
#         <h2>lotus-thai-cuisine-seattle-2</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>2446 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>, we mostly order delivery , and their drivers are professional and just so nice ! the food is quality , fresh , never had a bad sushi or noodle</p>
#     </div>
# 0.550076211445
#     <div>
#         <h2>thai-of-wedgwood-seattle-2</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>4508 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>bites . but i 'm still chewing . we ordered some takeout at work , and were saddened that we had called just a little too late for delivery .</p>
#     </div>
# 0.549936114315
#     <div>
#         <h2>thai-ginger-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>4353 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>, a wide , savory noodle sish . '' '' i give two thumbs up to the crab fried rice . '' '' they always got my order right and</p>
#     </div>
# 0.544352785038
#     <div>
#         <h2>Lotus Thai Cuisine</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>2385 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>friendly and kind . they put a huge order together in no time at all and the food was perfect . the dumplings were tinier than i was expecting but</p>
#     </div>
# 0.517815410795
#     <div>
#         <h2>Sea-Thai Restaurant</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>8448 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>the opportunity of meeting . in response to deliveries this is a very small family owned shop generally consisting of only one driver . they deliver to countless areas including</p>
#     </div>
# 0.5177356611
#     <div>
#         <h2>Amazing Thai Cuisine</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>7309 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>stomach ca n't handle really spicy foods so i usually find a few safe dishes i like and stick with them . that said even without the spice heat factor</p>
#     </div>
# 0.512931898679
#     <div>
#         <h2>Little Thai Restaurant</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>7192 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>food , good price , and great service . everything i ordered tasted good ; but i especially liked their crab noodle and their mango desserts . one of the</p>
#     </div>
# 0.512931898679
#     <div>
#         <h2>Ruane Thai</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>1718 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>, fatty n tender on the inside . i love it when you can go into a place that makes food just as great and comforting as a home cooked</p>
#     </div>
# 0.512705126985
#     <div>
#         <h2>Thai Ginger</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>7206 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>hh , and , really , cannot see making it a third time . the hh noshes , while reasonably priced , are pretty mediocre . on my most recent</p>
#     </div>
# 0.510255602244
#     <div>
#         <h2>The Patio Fine Thai</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>5207 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>more . i have been less impressed when eating in the restaurant - though it is clean and cute , i feel like th value / size / quantity is</p>
#     </div>
# 0.509638862083
#     <div>
#         <h2>ruane-thai-burien</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>1779 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>, we mostly order delivery , and their drivers are professional and just so nice ! the food is quality , fresh , never had a bad sushi or noodle</p>
#     </div>
# 0.509638862083
#     <div>
#         <h2>thai-on-alki-seattle</h2>
#         <span style='color: #ca0814;'><span></span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>171 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>this new addition to the broadway food scene . thai & sushi you say ? madness ! this means i can enjoy sushi while my boyfriend enjoys his favorite noodle</p>
#     </div>
# 0.507557213601
#     <div>
#         <h2>Thai On Alki</h2>
#         <span style='color: #ca0814;'><span></span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>115 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>food . regardless , i seem to eat it frequently thanks to the efforts of friends who do n't know they are addicts . i indulge them . maybe it</p>
#     </div>
# 0.507557213601
#     <div>
#         <h2>cha-cha-thai-tukwila</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>4484 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>service 10/10 i love this place ! was this review ... ? seattle , wa i guess i will start by saying that the server my partner and i had</p>
#     </div>
# 0.506754741083
#     <div>
#         <h2>thai-recipe-restaurant-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6787 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>new addition to the broadway food scene . thai & sushi you say ? madness ! this means i can enjoy sushi while my boyfriend enjoys his favorite noodle dishes</p>
#     </div>
# 0.50669974607
#     <div>
#         <h2>Thai Curry Simple</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>7263 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>is not fancy and is best for take out , but it is legit . the phanaeng curry was well executed . at the register they sell tons of cooking</p>
#     </div>
# 0.50669974607
#     <div>
#         <h2>Royal Thai Kitchen</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★</span><span style='color: #e4e4e4;'>★★★★</span>
#         <span style='color:#333;font-size:9px'>531 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>hungry but this did n't help . even the soy sauce could n't help the vegetables and tofu . service : adequate and quick ( it 's fast food )</p>
#     </div>
# 0.506541826202
#     <div>
#         <h2>royal-thai-kitchen-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★</span><span style='color: #e4e4e4;'>★★★★</span>
#         <span style='color:#333;font-size:9px'>593 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>favorite , local thai place and i can totally see why ! we dined for lunch and since it was an off hour , had the place to ourselves .</p>
#     </div>
# 0.506541826202
#     <div>
#         <h2>Chaiyo Thai Cuisine</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>5814 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>ambience as well ... recommended ! ! ! ! was this review ... ? seattle , wa if you own a business that has takeout or delivery service answering your</p>
#     </div>
# 0.506391028456
#     <div>
#         <h2>uma-thai-restaurant-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>6623 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai</span>
#         <p style='width:450px'>is in the kitchen . i must say the older lady makes the best pad kee mao i have ever had . it keeps me going back in hopes that</p>
#     </div>
# 0.50553624826
# <function __main__.show_conditional_probs>

# %%
from tsne import bh_sne

# %%
datum = bh_sne(model.object_matrix.get_value(borrow=True).astype(np.float64), d=2)

# %%
datum.shape
# Out:
# (6120, 2)

# %%
plt.scatter(datum[:,0], datum[:,1])

# %%
datum2 = bh_sne(model.object_matrix.get_value(borrow=True).astype(np.float64), d=2)

# %%
plt.scatter(datum2[:,0], datum2[:,1])

# %%
datum3 = bh_sne(model.norm_object_matrix.astype(np.float64), d=2)

# %%
def sort_data(dataset, labels):
    buckets = [[] for i in range(len(labels) + 1)]
    assigned = False
    for i in range(len(dataset)):
        assigned = False
        datacats = texts_data[i]["categories"]
        for k, cat in enumerate(labels):
            if cat in datacats:
                buckets[k+1].append(i)
                assigned = True
                break
        if not assigned:
            buckets[0].append(i)
    return buckets

def sort_data_by_text(dataset, keywords):
    buckets = [[] for i in range(len(keywords) + 1)]
    assigned = False
    for i in range(len(dataset)):
        assigned = False
        text = texts[i]
        for k, keyword in enumerate(keywords):
            if keyword in text:
                buckets[k+1].append(i)
                assigned = True
                break
        if not assigned:
            buckets[0].append(i)
    return buckets

def get_occurence_for_keyword(dataset, keyword):
    appearances = np.zeros(len(dataset), dtype=np.int32)
    assigned = False
    for i in range(len(dataset)):
        assigned = False
        text = texts[i]
        appearances[i] = text.count(keyword)
    return appearances

# %%
CATEGORIES = [         "vietnamese" ,   "thai", "tradamerican", "italian", "mexican", "chinese", "mediterranean"]
colors     = ["#c3c3c3",   "#6bd66f", "#dfa53d",      "#37c7ff", "#f92772", "#9951ff", "#4b8e84",       "#ff484e"]

category_buckets = sort_data(datum3, CATEGORIES)

fig = plt.figure(figsize=(8,8), dpi=300)
ax = fig.add_axes([1,1,1,1])

for bucket, color in zip(category_buckets[:-1], colors[:-1]):
    ax.scatter(datum3[bucket, 0], datum3[bucket, 1], c = color, edgecolor='none')

ax.legend(["other"] + CATEGORIES);
ax.axis("off")

# %%
CATEGORIES = [         "vietnamese" ,   "thai", "tradamerican", "italian", "mexican", "chinese", "mediterranean"]
colors     = ["#c3c3c3",   "#6bd66f", "#dfa53d",      "#37c7ff", "#f92772", "#9951ff", "#4b8e84",       "#ff484e"]

category_buckets = sort_data(datum3, CATEGORIES)

fig = plt.figure(figsize=(8,8), dpi=300)
ax = fig.add_axes([1,1,1,1])

for bucket, color in zip(category_buckets, colors):
    ax.scatter(datum3[bucket, 0], datum3[bucket, 1], c = color, edgecolor='none')

ax.legend(["other"] + CATEGORIES);
ax.set_title("T-sne projection of Seattle Yelp restaurants");
frax.axis("off");

# %%
from matplotlib import cm

colors     = ["#c3c3c3",  "#ff484e"]

occurences = np.log(1. + get_occurence_for_keyword(datum3, "spicy").astype(np.float64))

fig = plt.figure(figsize=(8,8), dpi=300)
ax = fig.add_axes([1,1,1,1])

scattered_spicy = ax.scatter(datum3[:, 0], datum3[:, 1], c = occurences, edgecolor='none', cmap = cm.Blues)
fig.colorbar(scattered_spicy)

ax.set_title("T-sne projection of Seattle Yelp restaurants, with log occurence of word spicy");
ax.axis("off");

# %%
CATEGORIES = [         "vietnamese" ,   "thai", "tradamerican", "italian", "mexican", "chinese", "mediterranean"]
colors     = ["#c3c3c3",   "#6bd66f", "#dfa53d",      "#37c7ff", "#f92772", "#9951ff", "#4b8e84",       "#ff484e"]

category_buckets = sort_data(datum3, CATEGORIES)

fig = plt.figure(figsize=(8,8), dpi=300)
ax = fig.add_axes([1,1,1,1])

for bucket, color in zip(category_buckets, colors):
    ax.scatter(datum2[bucket, 0], datum2[bucket, 1], c = color, edgecolor='none')

ax.legend(["other"] + CATEGORIES);
ax.set_title("T-sne projection of Seattle Yelp restaurants");
ax.axis("off")
# Out:
# (-60.0, 80.0, -60.0, 60.0)

# %%
model.most_similar_word("he", metric="euclidean")
# Out:
# [('$', 0.30527839064598083, 5297),
#  ('some', 0.34276440739631653, 25615),
#  ('she', 0.3840119540691376, 8369),
#  ('can', 0.3985272943973541, 19458),
#  ('more', 0.4018423557281494, 28229),
#  ('even', 0.408109188079834, 13495),
#  ('will', 0.41943085193634033, 15967),
#  ('would', 0.42333105206489563, 29889),
#  ('no', 0.4473765790462494, 22210),
#  ('but', 0.45836344361305237, 30452)]

# %%
for i, dist in model.most_similar_object(1306):
    present_restaurant(texts_data[i], text=texts[i])
# Out:
#     <div>
#         <h2>long-provincial-vietnamese-restaurant-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6556 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>lot in happy hours . prices are pretty reasonable . the service is not the best but the foods i am having there is so amazingly delicious that i do</p>
#     </div>
#     <div>
#         <h2>green-leaf-vietnamese-restaurant-seattle-3</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6604 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>( ordered some steamed rice and veggies dish ) and it was some of the worst food we 've ever had . but , the new years hangover demanded pho</p>
#     </div>
#     <div>
#         <h2>rose-pho-normandy-park</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>5062 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>, 2 denver , and 8 pleasanton-dublin restaurants i can recall eating at . it was so absolutely fantastic that we ate there twice in a row while on vacation</p>
#     </div>
#     <div>
#         <h2>bamboo-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6119 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>veggie pho- comes with a ton of basil and all the veggies are super fresh . i usually get this to go and end up with at least 4 meals</p>
#     </div>
#     <div>
#         <h2>bol-pho-bistro-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>5168 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>in the restaurant . that being said , this is my favorite place to get thai takeout in all of west seattle . i crave thai food about 3 times</p>
#     </div>
#     <div>
#         <h2>tamarind-tree-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6033 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>may want to walk to this place if you are n't used to really bad drivers and people with absolutely no skill for parking . asian immigrants have got to</p>
#     </div>
#     <div>
#         <h2>Mekong Village</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6540 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>want a quiet place to eat . for a wide range of vietnamese foods , mekong village is more a of destination spot in my view . their spring rolls</p>
#     </div>
#     <div>
#         <h2>green-leaf-vietnamese-restaurant-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>4597 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>from vietnam and we were a little worried that this place would be too `` americanized `` and it was with the decor but the food was soo good !</p>
#     </div>
#     <div>
#         <h2>mekong-village-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6315 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>pork vermicelli : in a word ... awesome by s n . '' but the veggie pho and and fresh veggie rolls were so damn good . '' '' the</p>
#     </div>
#     <div>
#         <h2>Bún - Vietnamese Creative Rice Noodles</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>7042 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>tables are n't crowded together and it was spacious . i ordered the beef short ribs from the regular menu ( $ 10 ) and lemongrass grilled chicken with vermicelli</p>
#     </div>
#     <div>
#         <h2>Tamarind Tree</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6030 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>may want to walk to this place if you are n't used to really bad drivers and people with absolutely no skill for parking . asian immigrants have got to</p>
#     </div>
#     <div>
#         <h2>la-lot-restaurant-and-bar-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>7160 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>did . if you want amazing pho go here ! i loved the tofu pho . it was so big and tasty . i see why it get s packed</p>
#     </div>
#     <div>
#         <h2>pho-an-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>5926 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>at thanh vi features the freshest ... read more '' seattle , wa i love , love , love this place . you must go . do n't be put</p>
#     </div>
#     <div>
#         <h2>pho-white-center-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>4981 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>been , i will be the happiest person . chan seattle did not disappoint in that respect . i finally made it to the restaurant on christmas eve to start</p>
#     </div>
#     <div>
#         <h2>just-pho-you-kent</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>3153 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>the staff was friendly and it was prepared very quickly and the cost was average ( about $ 8 for a small ) as i walked out back towards my</p>
#     </div>
#     <div>
#         <h2>pho-binh-seattle-2</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>1713 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>chef 's proper knowledge and technique . the vietnamese cuisine at thanh vi features the freshest and highest quality ingredients possible , culled from the bounty of ... read more</p>
#     </div>
#     <div>
#         <h2>thanh-thao-restaurant-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>5461 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>great . service is impeccable even with limited english . always welcomed with a smile . was this review ... ? seattle , wa maybe it 's just me during</p>
#     </div>
#     <div>
#         <h2>pho-sai-gon-restaurant-seattle</h2>
#         <span style='color: #ca0814;'><span></span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>330 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>once a week and they are friendly and speak english . not my favorite pho but good . i like a fattier , beefier broth with less aromatics . they</p>
#     </div>
#     <div>
#         <h2>pho-viet-anh-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6487 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>'ve had pho many places in the washington area , but this place is the tastiest . and fast ! i 'm usually in and out within half an hour</p>
#     </div>
#     <div>
#         <h2>time-4-pho-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>7199 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>yelp reviews and decided to go because i was on my way home . i 'm glad there is a pho place in magnolia . we 're a small neighborhood</p>
#     </div>

# %%
nearest_name("Bol Pho Bistro")
# Out:
# ('bol pho bistro', 1306, 0)

# %%
texts_data[1306]
# Out:
# {'categories': ['vietnamese'],
#  'id': 'bol-pho-bistro-seattle',
#  'rating': 4.0,
#  'price': '$$',
#  '_id': 'Bol Pho Bistro'}

# %%
nearest_name("Lemongrass")
# Out:
# ('lemongrass', 1334, 0)

# %%
show_conditional_probs_from_index([4796, 1334])
# Out:
#     <div>
#         <h2>wild-ginger-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>6415 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>asianfusion, thai, chinese</span>
#         <p style='width:450px'>our go-to chinese food delivery restaurant to our home in edmonds . i did n't think they delivered that far but they do , and they have always been timely</p>
#     </div>
# 0.551874775556
#     <div>
#         <h2>Lotus Asian Kitchen & Lounge</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>3967 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese, chinese, lounges</span>
#         <p style='width:450px'>placing a fried rolled up shell inside the spring roll . the mongolian beef had to of been the most tenderized beef i 've had at an asian restaurant .</p>
#     </div>
# 0.514038240492
#     <div>
#         <h2>lotus-asian-kitchen-and-lounge-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>4027 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese, chinese, lounges</span>
#         <p style='width:450px'>, if you reserve a table ahead of time , they usually get you seated right away . the parking lot is tiny , so consider parking on the street</p>
#     </div>
# 0.514038240492
#     <div>
#         <h2>Jelly Bar</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>2441 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese, lounges</span>
#         <p style='width:450px'>jellyfish tank by ave a . '' excellent late night happy hour starting at 10pm . '' '' ... dark but nice , especially to catch full view of the</p>
#     </div>
# 0.513850405734
#     <div>
#         <h2>jelly-bar-seattle-2</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>2484 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese, lounges</span>
#         <p style='width:450px'>really just the bar of long provincial , i like this place better . i think it 's because my expectations were lower , i come during happy hour so</p>
#     </div>
# 0.513850405734
#     <div>
#         <h2>Lee's Asian Restaurant</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>5345 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>chinese, thai</span>
#         <p style='width:450px'>beef is out of this world . honey glazed walnut prawns are must add well . explore the menu and you fill find your own gems . was this review</p>
#     </div>
# 0.509740201485
#     <div>
#         <h2>lees-asian-restaurant-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>5391 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>chinese, thai</span>
#         <p style='width:450px'>, we mostly order delivery , and their drivers are professional and just so nice ! the food is quality , ... '' read more '' south weymouth , ma</p>
#     </div>
# 0.509740201485
#     <div>
#         <h2>spicy-wok-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>1127 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>chinese, thai</span>
#         <p style='width:450px'>.spicy wok is a good alternative to new china . although you do n't get soup and an egg roll with your entree , spicy wok provides a clean atmosphere</p>
#     </div>
# 0.507295298098
#     <div>
#         <h2>herbs-thai-to-go-seattle</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>511 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai, chinese</span>
#         <p style='width:450px'>however , if you reserve a table ahead of time , they usually get you seated right away . the parking lot is tiny , so consider parking on the</p>
#     </div>
# 0.507295298098
#     <div>
#         <h2>Spicy Wok</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>1078 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>chinese, thai</span>
#         <p style='width:450px'>.spicy wok is a good alternative to new china . although you do n't get soup and an egg roll with your entree , spicy wok provides a clean atmosphere</p>
#     </div>
# 0.507291496334
#     <div>
#         <h2>Herbs Thai To Go</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>452 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai, chinese</span>
#         <p style='width:450px'>n't expect gourmet ) but the folks who work here are super friendly and generous and bump it up to a 4 star overall for me . i go here</p>
#     </div>
# 0.507291496334
#     <div>
#         <h2>Mai Thaiku</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>7609 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai, bars</span>
#         <p style='width:450px'>again . my experience was much better , and we have even gone back ! the waitresses were attentive and very sweet , the food was good , and i</p>
#     </div>
# 0.504285527063
#     <div>
#         <h2>Pho Mau</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>692 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese, bubbletea</span>
#         <p style='width:450px'>and cakes . i and my husband love to have some hot fresh baked croissant and coffee for breakfast ; so we read more '' wa , wa remember when</p>
#     </div>
# 0.503429259337
#     <div>
#         <h2>pho-mau-kent</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>647 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese, bubbletea</span>
#         <p style='width:450px'>liked your meal ? that place exists nowhere that i know of in modern life except in this little pho shop in kent . the food is 3-4 stars ,</p>
#     </div>
# 0.503429259337
#     <div>
#         <h2>108 Restaurant</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6199 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese, tradamerican</span>
#         <p style='width:450px'>! ! the pho is very comforting and tasty . i would recommend this place to any of my friends . the menu is huge and there is something for</p>
#     </div>
# 0.503417870059
#     <div>
#         <h2>108-restaurant-kent</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★★</span><span style='color: #e4e4e4;'>★</span>
#         <span style='color:#333;font-size:9px'>6199 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese, tradamerican</span>
#         <p style='width:450px'>! ! the pho is very comforting and tasty . i would recommend this place to any of my friends . the menu is huge and there is something for</p>
#     </div>
# 0.503417870059
#     <div>
#         <h2>Old Country Buffet</h2>
#         <span style='color: #ca0814;'><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★</span><span style='color: #e4e4e4;'>★★★</span>
#         <span style='color:#333;font-size:9px'>7845 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>newamerican, buffets, breakfast_brunch</span>
#         <p style='width:450px'>about 9 or 10 years old , back when the price was about $ 9 for a meal with drinks included - this had to be at least late 7777s</p>
#     </div>
# 0.50334823783
#     <div>
#         <h2>Ayutthaya Thai</h2>
#         <span style='color: #ca0814;'><span>$</span><span>$</span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★★★</span><span style='color: #e4e4e4;'>★★</span>
#         <span style='color:#333;font-size:9px'>5431 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>thai, bars</span>
#         <p style='width:450px'>is on the third floor of the building this restaurant is in . super convenient location for us and great prices . came by during happy hour and had the</p>
#     </div>
# 0.503284168207
#     <div>
#         <h2>pho-thuy-hong-seattle</h2>
#         <span style='color: #ca0814;'><span></span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★</span><span style='color: #e4e4e4;'>★★★★</span>
#         <span style='color:#333;font-size:9px'>341 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>at thanh vi features the freshest ... read more '' seattle , wa i would have given this place a 2 but man oh man the service was terrible .</p>
#     </div>
# 0.503049132187
#     <div>
#         <h2>Pho Thuy Hong</h2>
#         <span style='color: #ca0814;'><span></span></span><span style='color: #e4e4e4;'><span>$</span><span>$</span><span>$</span><span>$</span></span><br />
#         <span style='color: #feea60;'>★</span><span style='color: #e4e4e4;'>★★★★</span>
#         <span style='color:#333;font-size:9px'>311 words</span>
#         <br/>
#         <span style='color:#777:font-size:9px'>Categories: </span><span style='color:#333;font-size:13px'>vietnamese</span>
#         <p style='width:450px'>if i could recommend ... just do not go here . the soup ... just ok . it had the taste of pho but i would n't be surprised if</p>
#     </div>
# 0.503049132187

# %%
model.params[0].get_value(borrow=True).shape
# Out:
# (198, 220)

# %%
model.output_classes
# Out:
# array([5, 5], dtype=int32)
